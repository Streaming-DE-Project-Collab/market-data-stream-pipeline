# %%
from iexfinance.stocks import Stock, get_historical_data

# %%
import os
iex_token = os.getenv('IEX_TOKEN')

# %%
aapl = Stock('AAPL', output_format='json', token = iex_token)

# %%
dir(aapl)
# Out:
# ['_URLS',
#  '_VALID_API_VERSIONS',
#  '_VALID_FORMATS',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_convert_output',
#  '_execute_iex_query',
#  '_format_output',
#  '_get_endpoint',
#  '_get_field',
#  '_handle_error',
#  '_output_format',
#  '_output_format_one',
#  '_prepare_query',
#  '_validate_response',
#  'endpoints',
#  'fetch',
#  'get_advanced_stats',
#  'get_balance_sheet',
#  'get_beta',
#  'get_book',
#  'get_cash_flow',
#  'get_chart',
#  'get_close',
#  'get_company',
#  'get_company_name',
#  'get_delayed_quote',
#  'get_dividends',
#  'get_earnings',
#  'get_endpoints',
# ...

# %%
aapl.get_years_high()
# Out:
# 199.62

# %%
aapl.get_years_low()
# Out:
# 123.15

# %%
aapl.get_ytd_change()
# Out:
# 0.5369555801396514

# %%
aapl.get_volume()
# Out:
# 66831572

# %%
aapl.get_splits()
# Out:
# [{'declaredDate': None,
#   'description': 'Ordinary Shares',
#   'exDate': '2020-08-31',
#   'fromFactor': 1,
#   'ratio': 0.25,
#   'refid': 6705964,
#   'symbol': 'AAPL',
#   'toFactor': 4,
#   'id': 'SPLITS',
#   'key': 'AAPL',
#   'subkey': '6705964',
#   'date': 1598832000000,
#   'updated': 1652531945036.54}]

# %%
aapl.get_sector()
# Out:
# 'Manufacturing'

# %%
aapl.get_quote()
# Out:
# {'avgTotalVolume': 48000708,
#  'calculationPrice': 'close',
#  'change': 0.15,
#  'changePercent': 0.00076,
#  'close': 198.11,
#  'closeSource': 'official',
#  'closeTime': 1702587600060,
#  'companyName': 'Apple Inc',
#  'currency': 'USD',
#  'delayedPrice': 198.08,
#  'delayedPriceTime': 1702587581106,
#  'extendedChange': -0.16,
#  'extendedChangePercent': -0.00081,
#  'extendedPrice': 197.95,
#  'extendedPriceTime': 1702601988522,
#  'high': 199.62,
#  'highSource': '15 minute delayed price',
#  'highTime': 1702587599996,
#  'iexAskPrice': 0,
#  'iexAskSize': 0,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
#  'iexClose': 198.16,
#  'iexCloseTime': 1702587599885,
#  'iexLastUpdated': 1702587599885,
#  'iexMarketPercent': 0.030322090882435027,
#  'iexOpen': 198.08,
#  'iexOpenTime': 1702564200780,
#  'iexRealtimePrice': 198.16,
#  'iexRealtimeSize': 98,
#  'iexVolume': 2026473,
#  'lastTradeTime': 1702587599901,
#  'latestPrice': 198.11,
#  'latestSource': 'Close',
# ...

# %%
aapl.get_primary_exchange()
# Out:
# 'NASDAQ'

# %%
aapl.get_peers()
# Out:
# ['MSFT', 'HPQ', 'GOOG', 'AMZN', 'NFLX']

# %%
aapl.get_open_close()
# Out:
# {'open': {'price': 198.07, 'time': 1702564200728},
#  'close': {'price': 198.11, 'time': 1702587600060},
#  'high': 199.62,
#  'low': 196.16,
#  'volume': 55974698,
#  'symbol': 'AAPL'}

# %%
aapl.get_ohlc()
# Out:
# {'open': {'price': 198.07, 'time': 1702564200728},
#  'close': {'price': 198.11, 'time': 1702587600060},
#  'high': 199.62,
#  'low': 196.16,
#  'volume': 55974698,
#  'symbol': 'AAPL'}

# %%
aapl.get_key_stats()
# Out:
# {'companyName': 'Apple Inc',
#  'marketcap': 3078822785920,
#  'week52high': 198,
#  'week52low': 123.15,
#  'week52highSplitAdjustOnly': 198.23,
#  'week52lowSplitAdjustOnly': 124.17,
#  'week52change': 0.395501629119148,
#  'sharesOutstanding': 15552752000,
#  'float': 0,
#  'avg10Volume': 56092419,
#  'avg30Volume': 48000708,
#  'day200MovingAvg': 182.5,
#  'day50MovingAvg': 185.79,
#  'employees': 164000,
#  'ttmEPS': 6.13,
#  'ttmDividendRate': 0.9465536932059656,
#  'dividendYield': 0.004781540175823225,
#  'nextDividendDate': '',
#  'exDividendDate': '2023-11-10',
#  'nextEarningsDate': '2024-02-01',
#  'peRatio': 31.74207728150936,
#  'beta': 1.171879306839512,
#  'maxChangePercent': 76.37648530331458,
#  'year5ChangePercent': 3.844942742253256,
#  'year2ChangePercent': 0.14379018880396033,
#  'year1ChangePercent': 0.3738216058361741,
#  'ytdChangePercent': 0.5361955801396514,
#  'month6ChangePercent': 0.08569212873206689,
#  'month3ChangePercent': 0.13932501496385652,
# ...

# %%
aapl.get_financials()
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'accountsPayable': 62611000000,
#    'capitalSurplus': None,
#    'cashChange': 61555000000,
#    'cashFlow': 21598000000,
#    'cashFlowFinancing': -23153000000,
#    'changesInInventories': 6331000000,
#    'changesInReceivables': 60985000000,
#    'commonStock': 15599433000,
#    'costOfRevenue': 49071000000,
#    'currency': 'USD',
#    'currentAssets': 143566000000,
#    'currentCash': 61555000000,
#    'currentDebt': 15807000000,
#    'currentLongTermDebt': 15807000000,
#    'depreciation': 2653000000,
#    'dividendsPaid': None,
#    'ebit': 26969000000,
#    'EBITDA': 29622000000,
#    'exchangeRateEffect': None,
#    'filingType': '10-K',
#    'fiscalDate': '2023-09-30',
#    'fiscalQuarter': 4,
#    'fiscalYear': 2023,
#    'goodwill': 0,
#    'grossProfit': 40427000000,
#    'incomeTax': 4042000000,
#    'intangibleAssets': 0,
#    'interestIncome': 1002000000,
#    'inventory': 6331000000,
#    'investingActivityOther': None,
# ...

# %%
aapl.get_advanced_stats()
# Out:
# {'beta': 1.171879306839512,
#  'totalCash': 61555000000,
#  'currentDebt': 145308000000,
#  'revenue': 383285000000,
#  'grossProfit': 169148000000,
#  'totalRevenue': 383285000000,
#  'EBITDA': 125820000000,
#  'revenuePerShare': 24.64,
#  'revenuePerEmployee': 2607380.95,
#  'debtToEquity': 5.673462491552152,
#  'profitMargin': 0.2530623426432028,
#  'enterpriseValue': 3128355785920,
#  'enterpriseValueToRevenue': 8.16,
#  'priceToSales': 8.03,
#  'priceToBook': 49.54,
#  'forwardPERatio': 30.01769164710026,
#  'pegRatio': 93.05536380741458,
#  'peHigh': 11.929885083236506,
#  'peLow': 8.01854304813428,
#  'week52highDate': '2023-12-13',
#  'week52lowDate': '2023-01-03',
#  'putCallRatio': 0.49908112365450247,
#  'companyName': 'Apple Inc',
#  'marketcap': 3078822785920,
#  'week52high': 198,
#  'week52low': 123.15,
#  'week52highSplitAdjustOnly': 198.23,
#  'week52highDateSplitAdjustOnly': '2023-07-19',
#  'week52lowSplitAdjustOnly': 124.17,
# ...

# %%
aapl = Stock('AAPL', output_format='pandas', token = api_token)
aapl.get_balance_sheet().T
# Out:
#                             2023-11-03
# accountsPayable            62611000000
# capitalSurplus                    None
# commonStock                15599433000
# currency                           USD
# currentAssets             143566000000
# currentCash                61555000000
# currentLongTermDebt        15807000000
# filingType                        10-K
# fiscalDate                  2023-09-30
# fiscalQuarter                        4
# fiscalYear                        2023
# goodwill                             0
# intangibleAssets                     0
# inventory                   6331000000
# longTermDebt               95281000000
# longTermInvestments       209017000000
# minorityInterest                     0
# netTangibleAssets          62146000000
# otherAssets                64758000000
# otherCurrentAssets         14695000000
# otherCurrentLiabilities    66890000000
# otherLiabilities           49848000000
# propertyPlantEquipment     43715000000
# ...

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2017, 1, 1)
end = datetime(2018, 1, 1)

df = get_historical_data("AAPL", start, end)
df
# Out:
#               close     high      low     open   priceDate symbol     volume  \
# 2017-01-03  29.0375  29.0825    28.69    28.95  2017-01-03   AAPL  115127460
# 2017-01-04   29.005  29.1275  28.9375  28.9625  2017-01-04   AAPL   84472464
# 2017-01-05  29.1525  29.2161  28.9525    28.98  2017-01-05   AAPL   88774348
# 2017-01-06  29.4775    29.54  29.1175   29.195  2017-01-06   AAPL  127007600
# 2017-01-09  29.7475  29.8575   29.485  29.4875  2017-01-09   AAPL  134247792
# ...             ...      ...      ...      ...         ...    ...        ...
# 2017-12-22  43.7525   43.856   43.625    43.67  2017-12-22   AAPL   65397776
# 2017-12-26  42.6425  42.8675  42.4198     42.7  2017-12-26   AAPL  132742144
# 2017-12-27    42.65   42.695  42.4275   42.525  2017-12-27   AAPL   85992852
# 2017-12-28    42.77  42.9625    42.62    42.75  2017-12-28   AAPL   65920748
# 2017-12-29  42.3075  42.6475   42.305    42.63  2017-12-29   AAPL  103999688
#
# ...

# %%
df = get_historical_data("AAPL", "20190617", "20190618", close_only=True)
df
# Out:
#               close     volume
# 2019-06-17  48.4725   58676576
# 2019-06-18  49.6125  106204016

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_intraday

date = datetime(2023, 11, 27)

get_historical_intraday("AAPL", date, output_format='pandas')
# Out:
#                      average    close        date    high      low  \
# 2023-11-27 09:30:00  190.086  190.190  2023-11-27  190.36  189.950
# 2023-11-27 09:31:00  190.049  190.160  2023-11-27  190.25  189.880
# 2023-11-27 09:32:00  189.935  189.770  2023-11-27  190.13  189.760
# 2023-11-27 09:33:00      NaN      NaN  2023-11-27     NaN      NaN
# 2023-11-27 09:34:00  189.599  189.525  2023-11-27  189.66  189.525
# ...                      ...      ...         ...     ...      ...
# 2023-11-27 15:56:00      NaN      NaN  2023-11-27     NaN      NaN
# 2023-11-27 15:57:00  189.713  189.680  2023-11-27  189.74  189.680
# 2023-11-27 15:58:00  189.695  189.710  2023-11-27  189.74  189.620
# 2023-11-27 15:59:00  189.826  189.790  2023-11-27  189.87  189.770
# 2023-11-27 16:00:00      NaN      NaN  2023-11-27     NaN      NaN
#
#                      marketAverage  marketClose  marketHigh  marketLow  \
# 2023-11-27 09:30:00         190.11     190.2676    190.3900   189.9000
# ...

# %%
from iexfinance.stocks import get_market_gainers
get_market_gainers()
# Out:
#         avgTotalVolume calculationPrice  change  changePercent  close  \
# symbol
# STTK           2888876            close    2.10        0.43210   6.96
# CDXS            718496            close    0.86        0.41148   2.95
# XOS              25823            close    2.44        0.40871   8.41
# TLSI             70694            close    2.00        0.33613   7.95
# SNCE             18464            close    1.08        0.26406   5.17
# GKOS            532230            close   15.32        0.25356  75.74
# MAXN           2613845            close    1.10        0.24017   5.68
# LDI             327131            close    0.50        0.22831   2.69
# LOOP             21437            close    0.76        0.21229   4.34
#
#        closeSource      closeTime                    companyName currency  \
# symbol
# STTK      official  1702587600010              Shattuck Labs Inc      USD
# CDXS      official  1702587600057                   Codexis Inc.      USD
# ...

# %%
from iexfinance.refdata import get_symbols
symbols = get_symbols()

# %%
symbols
# Out:
#       symbol exchange exchangeSuffix                    exchangeName  \
# 0          A     XNYS                    New York Stock Exchange Inc
# 1         AA     XNYS                    New York Stock Exchange Inc
# 2        AAA     ARCX                                      Nyse Arca
# 3       AAAU     BATS                 Cboe Bzx U S Equities Exchange
# 4       AACG     XNAS                             Nasdaq All Markets
# ...      ...      ...            ...                             ...
# 10959   ZVRA     XNAS                             Nasdaq All Markets
# 10960   ZVSA     XNAS                             Nasdaq All Markets
# 10961    ZWS     XNYS                    New York Stock Exchange Inc
# 10962   ZYME     XNAS                             Nasdaq All Markets
# 10963   ZYXI     XNAS                             Nasdaq All Markets
#
#       exchangeSegment              exchangeSegmentName  \
# 0                XNYS      New York Stock Exchange Inc
# ...

# %%
type(symbols['symbol'].unique())
# Out:
# numpy.ndarray
